# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import statsmodels.api as sm
import patsy

# %%
df = pd.read_excel("./data/data_2019.xlsx")

# %%
df.columns
# Out:
# Index(['hhid', 'DR', 'DEP', 'INS', 'STO', 'DEBT', 'INC', 'EDU', 'SIZE', 'AGE',
#        'RUR', 'DIFI'],
#       dtype='object')

# %%
df.columns = ["hhid", "Rate", "Deposits", "Insurance", "Stock", "Debt", "Income", "Education", "Size", "Age", "Rural", "DIFI"]

# %%
df_ln = df.copy()

# %%
df_ln['Deposits'] = np.log(df_ln['Deposits'])
df_ln['Insurance'] = np.log(df_ln['Insurance'])
df_ln['Stock'] = np.log(df_ln['Stock'])
df_ln['Debt'] = np.log(df_ln['Debt'])
df_ln['Income'] = np.log(df_ln['Income'])
df_ln['Education'] = np.log(df_ln['Education'])
df_ln['Size'] = np.log(df_ln['Size'])
df_ln['Age'] = np.log(df_ln['Age'])
df_ln['Rural'] = np.log(df_ln['Rural'])
df_ln.replace([np.inf, -np.inf], 0.01, inplace=True)
# Out:
# C:\Users\linji\miniconda3\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\linji\miniconda3\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
y, X = patsy.dmatrices('Rate ~ Deposits + Insurance + Stock + Debt + Income + Education + Size + Age + Rural + DIFI', data=df, return_type='dataframe')
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rate   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     335.6
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:29:28   Log-Likelihood:                 6483.1
# No. Observations:               34502   AIC:                        -1.294e+04
# Df Residuals:                   34491   BIC:                        -1.285e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3607      0.013     27.367      0.000       0.335       0.387
# Deposits    5.323e-08   6.94e-09      7.670      0.000    3.96e-08    6.68e-08
# Insurance   5.009e-08   6.97e-09      7.181      0.000    3.64e-08    6.38e-08
# Stock       6.138e-08   2.16e-08      2.846      0.004    1.91e-08    1.04e-07
# Debt        2.254e-08   3.99e-09      5.645      0.000    1.47e-08    3.04e-08
# Income      4.573e-08   5.77e-09      7.931      0.000    3.44e-08     5.7e-08
# Education      0.0036      0.000     11.430      0.000       0.003       0.004
# Size           0.0318      0.001     42.753      0.000       0.030       0.033
# Age           -0.0005   8.95e-05     -6.125      0.000      -0.001      -0.000
# Rural          0.0181      0.002      7.356      0.000       0.013       0.023
# DIFI          -0.0004   3.47e-05    -10.581      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                     1815.817   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2111.650
# Skew:                           0.604   Prob(JB):                         0.00
# Kurtosis:                       2.891   Cond. No.                     3.64e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
res.mse_model
# Out:
# 13.496699233923437

# %%
y, X = patsy.dmatrices('Rate ~ Deposits + Insurance + Stock + Debt + Income + Education + Size + Age + Rural + DIFI', data=df_ln, return_type='dataframe')
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Rate   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     360.8
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:29:32   Log-Likelihood:                 6494.8
# No. Observations:               33706   AIC:                        -1.297e+04
# Df Residuals:                   33695   BIC:                        -1.287e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3318      0.023     14.261      0.000       0.286       0.377
# Deposits       0.0010      0.000      2.637      0.008       0.000       0.002
# Insurance      0.0005      0.000      1.911      0.056   -1.38e-05       0.001
# Stock          0.0049      0.001      8.780      0.000       0.004       0.006
# Debt           0.0043      0.000     17.637      0.000       0.004       0.005
# Income         0.0064      0.001      7.686      0.000       0.005       0.008
# Education      0.0069      0.002      3.671      0.000       0.003       0.011
# Size           0.0937      0.002     38.942      0.000       0.089       0.098
# Age           -0.0158      0.005     -3.387      0.001      -0.025      -0.007
# Rural         -1.4936      0.249     -6.004      0.000      -1.981      -1.006
# DIFI          -0.0003   3.51e-05     -8.922      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                     1816.167   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2120.769
# Skew:                           0.612   Prob(JB):                         0.00
# Kurtosis:                       2.897   Cond. No.                     7.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
res.mse_model
# Out:
# 14.37404936571038

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
import shap
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_clustering.py:35: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _pt_shuffle_rec(i, indexes, index_mask, partition_tree, M, pos):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_clustering.py:54: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def delta_minimization_order(all_masks, max_swap_size=100, num_passes=2):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_clustering.py:63: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window(order, start, length):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_clustering.py:69: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window_score_gain(masks, order, start, length):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_clustering.py:77: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _mask_delta_score(m1, m2):
# C:\Users\linji\miniconda3\lib\site-packages\shap\links.py:5: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def identity(x):
# C:\Users\linji\miniconda3\lib\site-packages\shap\links.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _identity_inverse(x):
# C:\Users\linji\miniconda3\lib\site-packages\shap\links.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def logit(x):
# C:\Users\linji\miniconda3\lib\site-packages\shap\links.py:20: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _logit_inverse(x):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_masked_model.py:363: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_single_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_masked_model.py:385: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_multi_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_masked_model.py:428: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _init_masks(cluster_matrix, M, indices_row_pos, indptr):
# C:\Users\linji\miniconda3\lib\site-packages\shap\utils\_masked_model.py:439: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _rec_fill_masks(cluster_matrix, indices_row_pos, indptr, indices, M, ind):
# C:\Users\linji\miniconda3\lib\site-packages\shap\maskers\_tabular.py:186: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _single_delta_mask(dind, masked_inputs, last_mask, data, x, noop_code):
# C:\Users\linji\miniconda3\lib\site-packages\shap\maskers\_tabular.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _delta_masking(masks, x, curr_delta_inds, varying_rows_out,
# C:\Users\linji\miniconda3\lib\site-packages\shap\maskers\_image.py:175: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _jit_build_partition_tree(xmin, xmax, ymin, ymax, zmin, zmax, total_ywidth, total_zwidth, M, clustering, q):
# C:\Users\linji\miniconda3\lib\site-packages\shap\explainers\_partition.py:676: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def lower_credit(i, value, M, values, clustering):
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.

# %%
df_ln.columns
# Out:
# Index(['hhid', 'Rate', 'Deposits', 'Insurance', 'Stock', 'Debt', 'Income',
#        'Education', 'Size', 'Age', 'Rural', 'DIFI'],
#       dtype='object')

# %%
y, X = patsy.dmatrices('Rate ~ Deposits + Insurance + Stock + Debt + Income + Education + Size + Age + Rural + DIFI', data=df_ln, return_type='dataframe')

# %%
X = X.drop(['Intercept'], axis=1)

# %%
model = XGBRegressor(n_estimators=100,learning_rate=0.3,max_depth=6,objective='reg:squarederror')

# %%
model.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.3,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 6,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
res = model.fit(X, y)

# %%
y_pred = model.predict(X)

# %%
mean_squared_error(y, y_pred)
# Out:
# 0.029494283642463055

# %%
explainer = shap.TreeExplainer(model)

# %%
shap_values = explainer.shap_values(X)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
df_ln.columns
# Out:
# Index(['hhid', 'Rate', 'Deposits', 'Insurance', 'Stock', 'Debt', 'Income',
#        'Education', 'Size', 'Age', 'Rural', 'DIFI'],
#       dtype='object')

# %%
shape_result = shap_values.copy()
shape_result = np.abs(shape_result)
shape_result = shape_result.sum(axis=0)/shape_result.shape[0]
shape_result
# Out:
# array([0.01186676, 0.00899115, 0.00140034, 0.01636933, 0.01547117,
#        0.00986434, 0.05138147, 0.01051858, 0.00845211, 0.02005092],
#       dtype=float32)

# %%
fig = shap.summary_plot(shap_values, X, plot_type="bar", show=False)
plt.savefig("shap_plot_2019.pdf", dpi=700)

# %%
fig = shap.summary_plot(shap_values, X, color_bar_label='Explanatory variables importance', plot_type="dot", cmap="coolwarm", show=False)
plt.savefig("summary_plot_2019.pdf", dpi=700)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
fig = shap.dependence_plot('Size', shap_values, X, interaction_index=None, show=False)
plt.savefig("size_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Debt', shap_values, X, interaction_index=None, show=False)
plt.savefig("debt_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Deposits', shap_values, X, interaction_index=None, show=False)
plt.savefig("deposits_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Age', shap_values, X, interaction_index=None, show=False)
plt.savefig("age_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Education', shap_values, X, interaction_index=None, show=False)
plt.savefig("education_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Insurance', shap_values, X, interaction_index=None, show=False)
plt.savefig("insurance_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Rural', shap_values, X, interaction_index=None, show=False)
plt.savefig("rural_plot_2019.pdf", dpi=700)

# %%
fig = shap.dependence_plot('Stock', shap_values, X, interaction_index=None, show=False)
plt.savefig("stock_plot_2019.pdf", dpi=700)

# %%
shap.dependence_plot('Insurance', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('Stock', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('Debt', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('Income', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('Size', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('DIFI', shap_values, X, interaction_index="Rural", show=False)

# %%
shap.dependence_plot('RUR', shap_values, X, interaction_index=None, show=False)

# %%
shap.dependence_plot('DIFI', shap_values, X, interaction_index=None, show=False)

# %%
shap.dependence_plot('EDU', shap_values, X, interaction_index='DEP', show=False)
